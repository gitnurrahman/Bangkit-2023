# %% [markdown]
# <a href="https://colab.research.google.com/github/gitnurrahman/Bangkit-2023/blob/main/Toursik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
tf.__version__
from typing import Dict, Text

# %%
data = pd.read_csv('Data.csv', on_bad_lines='skip', sep=';')
data['Jumlah Rating'] = data['Jumlah Rating'].replace(np.nan,'-')
data['Rating'] = data['Rating'].replace(np.nan,'-')
data['Address'] = data['Address'].replace(np.nan,'-')
data['Description'] = data['Description'].replace(np.nan,'-')
data['Harga'] = data['Harga'].replace(np.nan,'-')

# %%
data
# Out:
#            Province                  City  \
# 0              Aceh  Kabupaten Aceh Barat
# 1              Aceh  Kabupaten Aceh Barat
# 2              Aceh  Kabupaten Aceh Barat
# 3              Aceh  Kabupaten Aceh Barat
# 4              Aceh  Kabupaten Aceh Barat
# ...             ...                   ...
# 1112  South Sumatra       Kota Prabumulih
# 1113  South Sumatra       Kota Prabumulih
# 1114  South Sumatra       Kota Prabumulih
# 1115  South Sumatra       Kota Prabumulih
# 1116  South Sumatra       Kota Prabumulih
#
#                                     Place Rating Jumlah Rating     Type  \
# 0     Masjid Agung Baitul Makmur Meulaboh    4.7          2947   Religi
# 1                         Pantai Ceuremen      -             -     Alam
# 2                                Meureubo      -             -     Alam
# 3                  Tugu Kupiah Teuku Umar    4.6           866  Sejarah
# 4                        Pantai Suak Ribe    4.2           320     Alam
# ...
